# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('D:/data/TWO_CENTURIES_OF_UM_RACES.csv')
# Out:
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_7660\2192948197.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('D:/data/TWO_CENTURIES_OF_UM_RACES.csv')

# %%
df.head()
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# ...

# %%
df.tail()
# Out:
#          Year of event Event dates                                Event name  \
# 7461190           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461191           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461192           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461193           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461194           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 7461190                  65km                          2           4:33:20 h
# 7461191                  65km                          2           6:05:15 h
# 7461192                   24h                          3          241.000 km
# 7461193                   24h                          3          228.000 km
# 7461194                   24h                          3          224.000 km
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7461195 entries, 0 to 7461194
# Data columns (total 13 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Year of event              int64
#  1   Event dates                object
#  2   Event name                 object
#  3   Event distance/length      object
#  4   Event number of finishers  int64
#  5   Athlete performance        object
#  6   Athlete club               object
#  7   Athlete country            object
#  8   Athlete year of birth      float64
#  9   Athlete gender             object
#  10  Athlete age category       object
#  11  Athlete average speed      object
#  12  Athlete ID                 int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 740.0+ MB

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Year of event', 'Event dates', 'Event name', 'Event distance/length',
#        'Event number of finishers', 'Athlete performance', 'Athlete club',
#        'Athlete country', 'Athlete year of birth', 'Athlete gender',
#        'Athlete age category', 'Athlete average speed', 'Athlete ID'],
#       dtype='object')

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df[df['Event distance/length'].isin(['50km','50mi']) & (df['Year of event'] == 2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df['Year of event'].value_counts()
# Out:
# Year of event
# 2019    732207
# 2018    661483
# 2017    604638
# 2016    540073
# 2015    480722
#          ...
# 1802         1
# 1800         1
# 1944         1
# 1893         1
# 1945         1
# Name: count, Length: 146, dtype: int64

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
df2 = df[df['Event distance/length'].isin(['50km','50mi']) & (df['Year of event'] == 2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')]
df2
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2.head()
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# ...

# %%
df2.tail()
# Out:
#          Year of event Event dates  \
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                            Event name Event distance/length  \
# 2760957  Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760958  Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760959  Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760960  Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760961  Yankee Springs Fall Trail Run Festival (USA)                  50km
#
#          Event number of finishers Athlete performance        Athlete club  \
# 2760957                         30           7:07:48 h   *East Lansing, MI
# 2760958                         30           7:27:22 h  *Traverse City, MI
# ...

# %%
df2.shape
# Out:
# (26090, 13)

# %%
df2['Athelete_Age'] = 2020 - df['Athlete year of birth']
# Out:
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_7660\2341902596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athelete_Age'] = 2020 - df['Athlete year of birth']

# %%
df2.columns
# Out:
# Index(['Year of event', 'Event dates', 'Event name', 'Event distance/length',
#        'Event number of finishers', 'Athlete performance', 'Athlete club',
#        'Athlete country', 'Athlete year of birth', 'Athlete gender',
#        'Athlete age category', 'Athlete average speed', 'Athlete ID',
#        'Athelete_Age'],
#       dtype='object')

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_7660\1305527229.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head()
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20             3:17:55
# 2539946                         20             4:02:32
# 2539947                         20             4:07:57
# 2539948                         20             4:22:02
# ...

# %%
df2 = df2.drop(['Athlete club','Athlete country','Athlete year of birth'],axis = 1)

# %%
df2 = df2.drop(['Athlete age category'], axis = 1)

# %%
df2.head()
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance Athlete gender  \
# 2539945                         20             3:17:55              M
# 2539946                         20             4:02:32              M
# 2539947                         20             4:07:57              M
# ...

# %%
df2.columns
# Out:
# Index(['Year of event', 'Event dates', 'Event name', 'Event distance/length',
#        'Event number of finishers', 'Athlete performance', 'Athlete gender',
#        'Athlete average speed', 'Athlete ID', 'Athelete_Age'],
#       dtype='object')

# %%
df2.isnull().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# Athelete_Age                 233
# dtype: int64

# %%
df2.dropna(inplace = True)

# %%
df2[df2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, Athelete_Age]
# Index: []

# %%
df2.reset_index(drop = True)
# Out:
#        Year of event Event dates  \
# 0               2020  02.02.2020
# 1               2020  02.02.2020
# 2               2020  02.02.2020
# 3               2020  02.02.2020
# 4               2020  02.02.2020
# ...              ...         ...
# 25852           2020  03.10.2020
# 25853           2020  03.10.2020
# 25854           2020  03.10.2020
# 25855           2020  03.10.2020
# 25856           2020  03.10.2020
#
#                                           Event name Event distance/length  \
# 0      West Seattle Beach Run - Winter Edition (USA)                  50km
# 1      West Seattle Beach Run - Winter Edition (USA)                  50km
# 2      West Seattle Beach Run - Winter Edition (USA)                  50km
# 3      West Seattle Beach Run - Winter Edition (USA)                  50km
# 4      West Seattle Beach Run - Winter Edition (USA)                  50km
# ...                                              ...                   ...
# ...

# %%
df2.shape
# Out:
# (25857, 10)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# Athelete_Age                 float64
# dtype: object

# %%
df2['Athelete_Age'] = df2['Athelete_Age'].astype(int)

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# Athelete_Age                   int32
# dtype: object

# %%
sns.histplot(df2['Event distance/length'])
# Out:
# <Axes: xlabel='Event distance/length', ylabel='Count'>

# %%
sns.histplot(data  = df2, x = 'Event distance/length', hue = 'Athlete gender')
# Out:
# <Axes: xlabel='Event distance/length', ylabel='Count'>

# %%
sns.violinplot(data = df2, x = 'Event distance/length', y = 'Athlete average speed', hue = 'Athlete gender')
# Out:
# <Axes: xlabel='Event distance/length', ylabel='Athlete average speed'>

# %%
sns.barplot(data = df2, x = 'Athlete gender', y = 'Athlete average speed')
# Out:
# <Axes: xlabel='Athlete gender', ylabel='Athlete average speed'>

# %%
figure = plt.title('Comparision B/W Male and Female', size = 25)
sns.barplot(data = df2, x = 'Event distance/length', y = 'Athlete average speed', hue = 'Athlete gender')
# Out:
# <Axes: title={'center': 'Comparision B/W Male and Female'}, xlabel='Event distance/length', ylabel='Athlete average speed'>

# %%
df2.columns
# Out:
# Index(['Year of event', 'Event dates', 'Event name', 'Event distance/length',
#        'Event number of finishers', 'Athlete performance', 'Athlete gender',
#        'Athlete average speed', 'Athlete ID', 'Athelete_Age'],
#       dtype='object')

# %%
df2.groupby(['Event distance/length','Athlete gender'])['Athlete average speed'].mean()
# Out:
# Event distance/length  Athlete gender
# 50km                   F                 7.083011
#                        M                 7.738985
# 50mi                   F                 6.834371
#                        M                 7.257633
# Name: Athlete average speed, dtype: float64

# %%
df2.query('`Event distance/length` == "50mi"')\
   .groupby('Athelete_Age')['Athlete average speed']\
   .agg(['mean', 'count'])\
   .sort_values('mean', ascending=False)\
   .query('count > 19')
# Out:
#                   mean  count
# Athelete_Age
# 29            7.902252    135
# 23            7.779800     55
# 28            7.575252    107
# 30            7.569204    157
# 25            7.540923     91
# 31            7.451638    138
# 38            7.430022    231
# 35            7.422359    195
# 36            7.403854    185
# 26            7.379800     75
# 33            7.379188    149
# 22            7.367902     41
# 24            7.354274     73
# 42            7.327656    209
# 34            7.319011    182
# 40            7.310669    236
# 21            7.304658     38
# 20            7.293778     27
# 32            7.287969    162
# 39            7.283648    227
# 37            7.220493    221
# 27            7.201748    119
# 41            7.197017    179
# 45            7.130667    156
# 47            7.085410    156
# 44            7.052642    179
# 51            7.019379    124
# 46            6.897236    174
# 43            6.884225    187
# ...
